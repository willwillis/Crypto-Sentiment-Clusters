# %%
import pandas as pd
import os
import datetime as dt

# %%
unpickled_df = pd.read_pickle("../../data/clean/twitter_sentiment_full_1.pkl")
unpickled_df
# Out:
#                      created_at      screen_name  \
# 0     2019-10-31 23:58:56+00:00       Ricky_P007
# 1     2019-10-31 23:58:56+00:00  KennedyPattiso1
# 2     2019-10-31 23:58:55+00:00      BtcEthereum
# 3     2019-10-31 23:58:52+00:00    erickchan_XLM
# 4     2019-10-31 23:58:50+00:00     Researchiing
# ...                         ...              ...
# 99995 2019-10-20 09:36:17+00:00     kyoshiro7904
# 99996 2019-10-20 09:36:17+00:00         teasefun
# 99997 2019-10-20 09:36:14+00:00     roentgen1895
# 99998 2019-10-20 09:36:14+00:00       pepochiusu
# 99999 2019-10-20 09:36:14+00:00       pepochiusu
#
#                                                full_text                   id  \
# 0      RT @Delta_Exchange: How many coin logos do you...  1190055587255422977
# 1      RT @XRPcryptowolf: Intercontinental Exchange (...  1190055584910991360
# 2      Bitcoin Needs ‘Real Use Cases’ to Become Digit...  1190055581886775297
# 3      @CyhChloe @johnkim77 @jasminecoin @codeyisfun ...  1190055568678895618
# 4      RT @zerohedge: 11 Years Ago Today Satoshi Naka...  1190055561682964481
# ...                                                  ...                  ...
# 99995  RT @Cointelegraph: Bitcoin is poised for a dec...  1185852226905886720
# 99996  New Hot Girl  https://t.co/I86AMF3Rsm #paypig ...  1185852224381050880
# 99997  RT @OneHanSolo: Bitcoin Is Going Down! $XRP💥🚀😎...  1185852213865975808
# 99998                                     I LOVE Bitcoin  1185852212871757824
# 99999                                     I LOVE Bitcoin  1185852212871757824
#
#       lang  user_favourites_count  user_followers_count  user_friends_count  \
# 0       en                    532                    84                 246
# 1       en                  17182                  1051                1969
# 2       en                    384                   351                 526
# 3       en                   3051                   388                1086
# 4       en                      8                    12                  30
# ...    ...                    ...                   ...                 ...
# 99995   en                  66517                  1131                 395
# 99996   en                      3                    79                  81
# 99997   en                   9877                   389                1778
# 99998   en                      3                   414                 835
# 99999   en                      3                   414                 835
#
#                      user_location  \
# 0             Citeureup, Indonesia
# 1                    Liechtenstein
# 2                      Cyber Space
# 3                         Cambodia
# 4                             None
# ...                            ...
# 99995                    Australia
# 99996              Los Angeles, CA
# 99997  Planet $LINK To Moon 🌎⚡️🚀🌕
# 99998                         名古屋市
# 99999                         名古屋市
#
#                                   user_profile_image_url  ...  \
# 0      http://pbs.twimg.com/profile_images/1188757498...  ...
# 1      http://pbs.twimg.com/profile_images/3788000000...  ...
# 2      http://pbs.twimg.com/profile_images/8792232595...  ...
# 3      http://pbs.twimg.com/profile_images/1174348587...  ...
# 4      http://abs.twimg.com/sticky/default_profile_im...  ...
# ...                                                  ...  ...
# 99995  http://pbs.twimg.com/profile_images/9184749480...  ...
# 99996  http://pbs.twimg.com/profile_images/8888074735...  ...
# 99997  http://pbs.twimg.com/profile_images/1192950664...  ...
# 99998  http://pbs.twimg.com/profile_images/7702783583...  ...
# 99999  http://pbs.twimg.com/profile_images/7702783583...  ...
#
#                                                 mentions  \
# 0                                       [Delta_Exchange]
# 1                                        [XRPcryptowolf]
# 2                                                     []
# 3      [CyhChloe, johnkim77, jasminecoin, codeyisfun,...
# 4                                            [zerohedge]
# ...                                                  ...
# 99995                                    [Cointelegraph]
# 99996                                                 []
# 99997                                       [OneHanSolo]
# 99998                                                 []
# 99999                                                 []
#
#                                              mention_ids quoted_quote_count  \
# 0                                   [994891951160864769]                NaN
# 1                                   [944462285573099520]                NaN
# 2                                                     []                NaN
# 3      [1059871115236073473, 26448153, 11864798016930...                NaN
# 4                                             [18856867]                NaN
# ...                                                  ...                ...
# 99995                                       [2207129125]                NaN
# 99996                                                 []                NaN
# 99997                               [952103061023059968]                NaN
# 99998                                                 []                NaN
# 99999                                                 []                NaN
#
#       quoted_reply_count quoted_retweet_count  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ...                  ...                  ...
# 99995                NaN                  NaN
# 99996                NaN                  NaN
# 99997                NaN                  NaN
# 99998                NaN                  NaN
# 99999                NaN                  NaN
#
#                                             clean_tokens  compound  negative  \
# 0      [rt, deltaexchange, many, coin, logo, see, ima...     0.000     1.000
# 1      [rt, xrpcryptowolf, intercontinental, exchange...     0.000     0.865
# 2      [bitcoin, need, real, use, case, become, digit...     0.000     1.000
# 3      [cyhchloe, johnkim, jasminecoin, codeyisfun, c...     0.000     0.732
# 4      [rt, zerohedge, year, ago, today, satoshi, nak...     0.000     1.000
# ...                                                  ...       ...       ...
# 99995  [rt, cointelegraph, bitcoin, poised, decisive,...     0.141     0.470
# 99996  [new, hot, girl, paypig, findom, bitcoin, btc,...     0.140     0.860
# 99997              [rt, onehansolo, bitcoin, going, xrp]     0.000     1.000
# 99998                                    [love, bitcoin]     0.000     0.192
# 99999                                    [love, bitcoin]     0.000     0.192
#
#       neutral  positive
# 0       0.000    0.0000
# 1       0.135    0.3612
# 2       0.000    0.0000
# 3       0.268    0.5106
# 4       0.000    0.0000
# ...       ...       ...
# 99995   0.389    0.4019
# 99996   0.000   -0.0772
# 99997   0.000    0.0000
# 99998   0.808    0.6369
# 99999   0.808    0.6369
#
# [100000 rows x 23 columns]

# %%
#unpickled_df2 = pd.read_pickle("../../data/clean/twitter_sentiment2.pkl")
#unpickled_df2

# %%
unpickled_df2 = pd.read_pickle("../../data/clean/twitter_sentiment_full_2.pkl")
unpickled_df2
# Out:
#                       created_at      screen_name  \
# 100000 2019-10-30 20:58:57+00:00  FloraSm95414462
# 100001 2019-10-30 20:58:55+00:00       ryzecrypto
# 100002 2019-10-30 20:58:52+00:00   CoinsChronicle
# 100003 2019-10-30 20:58:45+00:00           kcprgm
# 100004 2019-10-30 20:58:43+00:00    formerlazyguy
# ...                          ...              ...
# 203995 2019-10-27 21:41:59+00:00         creep2oo
# 203996 2019-10-27 21:41:55+00:00    humble_crypto
# 203997 2019-10-27 21:41:47+00:00    Tylerderden23
# 203998 2019-10-27 21:41:47+00:00    Tylerderden23
# 203999 2019-10-27 21:41:46+00:00  FrancesMcIntos1
#
#                                                 full_text  \
# 100000  Invest today to know how bitcoin investment wo...
# 100001  David Jevans, CEO of CipherTrace, talking abou...
# 100002  3.f/ #xitcoin the new #bitcoin.\nSource - http...
# 100003  RT @Uptrennd: We have seen so much positive/bu...
# 100004  RT @MrMichaelNye: The first episode of @Whatis...
# ...                                                   ...
# 203995  Initiative Q is not the new Bitcoin, but here’...
# 203996  @Bitcoin_Vending Keep 'Steaking' :) https://t....
# 203997  RT @hodlonaut: Bitcoin, you're not fooling any...
# 203998  RT @hodlonaut: Bitcoin, you're not fooling any...
# 203999  RT @VladoBotsvadze: Amazon has almost no store...
#
#                          id lang  user_favourites_count  user_followers_count  \
# 100000  1189647904006377476   en                  11524                   809
# 100001  1189647895240294400   en                   3049                   431
# 100002  1189647881411665921   en                      2                    81
# 100003  1189647852537925632   en                   2322                  2031
# 100004  1189647847064367104   en                    906                   279
# ...                     ...  ...                    ...                   ...
# 203995  1188571571792814081   en                     19                    49
# 203996  1188571551593050113   en                    251                    39
# 203997  1188571519842209792   en                   3304                   120
# 203998  1188571519842209792   en                   3304                   120
# 203999  1188571515119439872   en                  19890                   789
#
#         user_friends_count    user_location  \
# 100000                 994  Washington, USA
# 100001                 389      Atlanta, GA
# 100002                   1             None
# 100003                2689             None
# 100004                 731             None
# ...                    ...              ...
# 203995                 339           London
# 203996                  81             None
# 203997                 899             None
# 203998                 899             None
# 203999                 721               UK
#
#                                    user_profile_image_url  ...  \
# 100000  http://pbs.twimg.com/profile_images/1187813189...  ...
# 100001  http://pbs.twimg.com/profile_images/1143547929...  ...
# 100002  http://pbs.twimg.com/profile_images/1077689896...  ...
# 100003  http://pbs.twimg.com/profile_images/1163069091...  ...
# 100004  http://pbs.twimg.com/profile_images/1188979627...  ...
# ...                                                   ...  ...
# 203995  http://pbs.twimg.com/profile_images/1171428022...  ...
# 203996  http://pbs.twimg.com/profile_images/1114159926...  ...
# 203997  http://pbs.twimg.com/profile_images/1028086395...  ...
# 203998  http://pbs.twimg.com/profile_images/1028086395...  ...
# 203999  http://pbs.twimg.com/profile_images/6395055066...  ...
#
#                                                 mentions  \
# 100000                                                []
# 100001                                                []
# 100002                                                []
# 100003                                 [Uptrennd, Bakkt]
# 100004  [MrMichaelNye, WhatisCrypto, lopp, MrMichaelNye]
# ...                                                  ...
# 203995                                 [ConversationEDU]
# 203996                                 [Bitcoin_Vending]
# 203997                                       [hodlonaut]
# 203998                                       [hodlonaut]
# 203999                                  [VladoBotsvadze]
#
#                                               mention_ids quoted_quote_count  \
# 100000                                                 []                NaN
# 100001                                                 []                NaN
# 100002                                                 []                5.0
# 100003         [1076093386413662210, 1025229076339060736]                NaN
# 100004  [3249465024, 1065722408332476416, 23618940, 32...                NaN
# ...                                                   ...                ...
# 203995                                        [224495471]                NaN
# 203996                              [1040217716496498688]               14.0
# 203997                               [852259884175372290]                NaN
# 203998                               [852259884175372290]                NaN
# 203999                                        [373883201]                NaN
#
#        quoted_reply_count quoted_retweet_count  \
# 100000                NaN                  NaN
# 100001                NaN                  NaN
# 100002                2.0                 10.0
# 100003                NaN                  NaN
# 100004                NaN                  NaN
# ...                   ...                  ...
# 203995                NaN                  NaN
# 203996                0.0                  0.0
# 203997                NaN                  NaN
# 203998                NaN                  NaN
# 203999                NaN                  NaN
#
#                                              clean_tokens  compound  negative  \
# 100000  [invest, today, know, bitcoin, investment, wor...     0.000     0.717
# 100001  [david, jevans, ceo, ciphertrace, talking, tra...     0.000     1.000
# 100002  [f, xitcoin, new, bitcoinsource, httpstcozslyz...     0.000     1.000
# 100003  [rt, uptrennd, seen, much, positivebullish, ne...     0.000     0.889
# 100004  [rt, mrmichaelnye, first, episode, whatiscrypt...     0.000     1.000
# ...                                                   ...       ...       ...
# 203995  [initiative, q, new, bitcoin, here, idea, valu...     0.000     0.745
# 203996                   [bitcoinvending, keep, steaking]     0.000     1.000
# 203997  [rt, hodlonaut, bitcoin, youre, fooling, anyon...     0.406     0.594
# 203998  [rt, hodlonaut, bitcoin, youre, fooling, anyon...     0.406     0.594
# 203999  [rt, vladobotsvadze, amazon, almost, store, ub...     0.000     0.786
#
#        neutral  positive
# 100000   0.283    0.8271
# 100001   0.000    0.0000
# 100002   0.000    0.0000
# 100003   0.111    0.1280
# 100004   0.000    0.0000
# ...        ...       ...
# 203995   0.255    0.3400
# 203996   0.000    0.0000
# 203997   0.000   -0.4767
# 203998   0.000   -0.4767
# 203999   0.214    0.3687
#
# [104000 rows x 23 columns]

# %%
concat_df = pd.concat([unpickled_df, unpickled_df2])

# %%
price_data = pd.read_csv("../../data/price_data/bitcoin_hourly.csv")
price_data
# Out:
#                date_time    close  volumefrom
# 0    2019-10-15 00:00:00  8378.45     1464.67
# 1    2019-10-15 01:00:00  8342.38      464.00
# 2    2019-10-15 02:00:00  8351.43      487.40
# 3    2019-10-15 03:00:00  8329.13      332.29
# 4    2019-10-15 04:00:00  8350.23      528.90
# ..                   ...      ...         ...
# 403  2019-10-31 19:00:00  9251.18      796.60
# 404  2019-10-31 20:00:00  9197.68     1888.84
# 405  2019-10-31 21:00:00  9144.69     4624.81
# 406  2019-10-31 22:00:00  9136.74      846.99
# 407  2019-10-31 23:00:00  9157.52      601.09
#
# [408 rows x 3 columns]

# %%
price_data = price_data.rename(columns={"date_time": "created_at", 'volumefrom': 'volume'})
price_data
# Out:
#               created_at    close   volume
# 0    2019-10-15 00:00:00  8378.45  1464.67
# 1    2019-10-15 01:00:00  8342.38   464.00
# 2    2019-10-15 02:00:00  8351.43   487.40
# 3    2019-10-15 03:00:00  8329.13   332.29
# 4    2019-10-15 04:00:00  8350.23   528.90
# ..                   ...      ...      ...
# 403  2019-10-31 19:00:00  9251.18   796.60
# 404  2019-10-31 20:00:00  9197.68  1888.84
# 405  2019-10-31 21:00:00  9144.69  4624.81
# 406  2019-10-31 22:00:00  9136.74   846.99
# 407  2019-10-31 23:00:00  9157.52   601.09
#
# [408 rows x 3 columns]

# %%
#price_data = price_data.set_index('created_at')

# %%
price_data
# Out:
#               created_at    close   volume
# 0    2019-10-15 00:00:00  8378.45  1464.67
# 1    2019-10-15 01:00:00  8342.38   464.00
# 2    2019-10-15 02:00:00  8351.43   487.40
# 3    2019-10-15 03:00:00  8329.13   332.29
# 4    2019-10-15 04:00:00  8350.23   528.90
# ..                   ...      ...      ...
# 403  2019-10-31 19:00:00  9251.18   796.60
# 404  2019-10-31 20:00:00  9197.68  1888.84
# 405  2019-10-31 21:00:00  9144.69  4624.81
# 406  2019-10-31 22:00:00  9136.74   846.99
# 407  2019-10-31 23:00:00  9157.52   601.09
#
# [408 rows x 3 columns]

# %%
#price_data.groupby(pd.Grouper(key='date_time', freq='60m', axis=1))

# %%
#head=unpickled_df.head(10)

# %%
#head

# %%
#test_df = unpickled_df[['created_at', 'compound', 'id', 'user_favourites_count', 'screen_name']].copy()
#test_df

# %%
#test = test_df.drop_duplicates(subset=['compound'])
#test

# %%
#binned_df = test_df.groupby([test_df['created_at'].dt.to_period('H'), 'user_favourites_count']).count().unstack()
# Droping unnecessary column level
#binned_df.columns = binned_df.columns.droplevel()
#binned_df.plot(kind='bar', legend=False)

# %%
#binned_df

# %%
#grouped_df = test_df.groupby([test_df['created_at'].dt.to_period('H'), 'user_favourites_count', 'screen_name', 'compound', 'id'])
#big_df

# %%
#df = pd.DataFrame(grouped_df.size().reset_index(level=['created_at']))
#df

# %%
#df.to_csv('model.csv')

# %%
#binned_d = price_data.groupby([price_data['date_time'].dt.to_period('D'), 'close']).count().unstack()
# Droping unnecessary column level
#binned_d.columns = binned_d.columns.droplevel()
#binned_d.plot(kind='bar')

# %%
model_data = concat_df[['created_at', 'negative', 'neutral', 'positive', 'clean_tokens']].copy()
model_data
# Out:
#                       created_at  negative  neutral  positive  \
# 0      2019-10-31 23:58:56+00:00     1.000    0.000    0.0000
# 1      2019-10-31 23:58:56+00:00     0.865    0.135    0.3612
# 2      2019-10-31 23:58:55+00:00     1.000    0.000    0.0000
# 3      2019-10-31 23:58:52+00:00     0.732    0.268    0.5106
# 4      2019-10-31 23:58:50+00:00     1.000    0.000    0.0000
# ...                          ...       ...      ...       ...
# 203995 2019-10-27 21:41:59+00:00     0.745    0.255    0.3400
# 203996 2019-10-27 21:41:55+00:00     1.000    0.000    0.0000
# 203997 2019-10-27 21:41:47+00:00     0.594    0.000   -0.4767
# 203998 2019-10-27 21:41:47+00:00     0.594    0.000   -0.4767
# 203999 2019-10-27 21:41:46+00:00     0.786    0.214    0.3687
#
#                                              clean_tokens
# 0       [rt, deltaexchange, many, coin, logo, see, ima...
# 1       [rt, xrpcryptowolf, intercontinental, exchange...
# 2       [bitcoin, need, real, use, case, become, digit...
# 3       [cyhchloe, johnkim, jasminecoin, codeyisfun, c...
# 4       [rt, zerohedge, year, ago, today, satoshi, nak...
# ...                                                   ...
# 203995  [initiative, q, new, bitcoin, here, idea, valu...
# 203996                   [bitcoinvending, keep, steaking]
# 203997  [rt, hodlonaut, bitcoin, youre, fooling, anyon...
# 203998  [rt, hodlonaut, bitcoin, youre, fooling, anyon...
# 203999  [rt, vladobotsvadze, amazon, almost, store, ub...
#
# [204000 rows x 5 columns]

# %%
#bins by the hour
grouped_model = model_data.groupby([model_data['created_at'].dt.to_period('H'), 'negative', 'positive', 'neutral'])
# Out:
# C:\Users\Sidearm\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %%
#change groupbyDataFrame to regular df
model_df = pd.DataFrame(grouped_model.size().reset_index(level=['created_at']))
model_df
# Out:
#                                  created_at    0
# negative positive neutral
# 0.222    -0.7184  0.000    2019-10-15 00:00    1
# 0.291    -0.7506  0.169    2019-10-15 00:00    1
# 0.316     0.8689  0.684    2019-10-15 00:00    1
# 0.377     0.5106  0.623    2019-10-15 00:00    9
# 0.398     0.8779  0.602    2019-10-15 00:00   12
# ...                                     ...  ...
# 0.922     0.3182  0.078    2019-10-31 23:00    1
# 0.925     0.3612  0.075    2019-10-31 23:00    1
# 0.936     0.1280  0.064    2019-10-31 23:00    1
# 0.950     0.0258  0.050    2019-10-31 23:00    1
# 1.000     0.0000  0.000    2019-10-31 23:00  237
#
# [92404 rows x 2 columns]

# %%
#model_df.to_csv('model.csv')

# %%
#grp = model_df.groupby(model_df['created_at'])['positive'].sum()

# %%
#grp = model_df.groupby(['created_at']).sum('positive')#)

# %%
mike_df = model_data.resample('H', on='created_at').mean()

# %%
mike_df
# Out:
#                            negative   neutral  positive
# created_at
# 2019-10-15 00:00:00+00:00  0.789136  0.175218  0.243769
# 2019-10-15 01:00:00+00:00  0.800804  0.142810  0.156272
# 2019-10-15 02:00:00+00:00  0.807638  0.149722  0.189712
# 2019-10-15 03:00:00+00:00  0.812648  0.146242  0.183761
# 2019-10-15 04:00:00+00:00  0.794686  0.160486  0.204969
# ...                             ...       ...       ...
# 2019-10-31 19:00:00+00:00  0.825726  0.129344  0.152173
# 2019-10-31 20:00:00+00:00  0.829012  0.127700  0.153295
# 2019-10-31 21:00:00+00:00  0.845378  0.117862  0.135068
# 2019-10-31 22:00:00+00:00  0.826362  0.119918  0.131794
# 2019-10-31 23:00:00+00:00  0.851836  0.112924  0.142856
#
# [408 rows x 3 columns]

# %%
mike_df = mike_df.sort_values(by='created_at', ascending=True)
mike_df
# Out:
#                            negative   neutral  positive
# created_at
# 2019-10-15 00:00:00+00:00  0.789136  0.175218  0.243769
# 2019-10-15 01:00:00+00:00  0.800804  0.142810  0.156272
# 2019-10-15 02:00:00+00:00  0.807638  0.149722  0.189712
# 2019-10-15 03:00:00+00:00  0.812648  0.146242  0.183761
# 2019-10-15 04:00:00+00:00  0.794686  0.160486  0.204969
# ...                             ...       ...       ...
# 2019-10-31 19:00:00+00:00  0.825726  0.129344  0.152173
# 2019-10-31 20:00:00+00:00  0.829012  0.127700  0.153295
# 2019-10-31 21:00:00+00:00  0.845378  0.117862  0.135068
# 2019-10-31 22:00:00+00:00  0.826362  0.119918  0.131794
# 2019-10-31 23:00:00+00:00  0.851836  0.112924  0.142856
#
# [408 rows x 3 columns]

# %%
mike_df = mike_df.reset_index()

# %%
#price_data = price_data.reset_index()
price_data
# Out:
#               created_at    close   volume
# 0    2019-10-15 00:00:00  8378.45  1464.67
# 1    2019-10-15 01:00:00  8342.38   464.00
# 2    2019-10-15 02:00:00  8351.43   487.40
# 3    2019-10-15 03:00:00  8329.13   332.29
# 4    2019-10-15 04:00:00  8350.23   528.90
# ..                   ...      ...      ...
# 403  2019-10-31 19:00:00  9251.18   796.60
# 404  2019-10-31 20:00:00  9197.68  1888.84
# 405  2019-10-31 21:00:00  9144.69  4624.81
# 406  2019-10-31 22:00:00  9136.74   846.99
# 407  2019-10-31 23:00:00  9157.52   601.09
#
# [408 rows x 3 columns]

# %%
#test = pd.to_datetime(price_data.created_at[100], unit='ns')
#test

# %%
#test2 = pd.to_datetime(mike_df.created_at[100], unit='ns')
#test2

# %%
#test1 = dt.strptime(test, "%Y-%m-%d %H:%M:%S")

# %%
#test_df = pd.to_datetime(mike_df.created_at[399], unit='ns')
#test_df

# %%
#price_test = test.strftime("%Y-%m-%d %H:%M:%S")
#price_test

# %%
#mike_test = test_df.strftime("%Y-%m-%d %H:%M:%S")
#mike_test

# %%
#date_time_obj = datetime.strptime(mike_test, '%Y-%m-%d %H:%M:%S')
#date_time_obj
# Out:
# datetime.datetime(2019, 10, 31, 15, 0)

# %%
#datetimeObj = datetime.strptime(mike_test, '%Y-%m-%d %H:%M:%S')
#print(datetimeObj)

# %%
#mike_df.iloc[0][0]

# %%
mike_df.iloc[10][0]
# Out:
# Timestamp('2019-10-15 10:00:00+0000', tz='UTC', freq='H')

# %%
#def timestamp_to_str(df):
    #"""convert timestamp column to str column"""
    #counter = 0
    #df['time_str'] = pd.Series()
    #for hour in df['created_at']:
        #df['time_str'][counter]=hour.strftime("%Y-%m-%d %H:%M:%S")
        #counter+=1
    #return df

# %%
#tweet_df = timestamp_to_str(mike_df)
#tweet_df

# %%
#tweet_df.set_index('time_str')

# %%
#price_df = timestamp_to_str(price_data)

# %%
price_data.iloc[0][0]
# Out:
# '2019-10-15 00:00:00'

# %%
price_data = price_data.rename(columns={"created_at":"time_str"})
price_data
# Out:
#                 time_str    close   volume
# 0    2019-10-15 00:00:00  8378.45  1464.67
# 1    2019-10-15 01:00:00  8342.38   464.00
# 2    2019-10-15 02:00:00  8351.43   487.40
# 3    2019-10-15 03:00:00  8329.13   332.29
# 4    2019-10-15 04:00:00  8350.23   528.90
# ..                   ...      ...      ...
# 403  2019-10-31 19:00:00  9251.18   796.60
# 404  2019-10-31 20:00:00  9197.68  1888.84
# 405  2019-10-31 21:00:00  9144.69  4624.81
# 406  2019-10-31 22:00:00  9136.74   846.99
# 407  2019-10-31 23:00:00  9157.52   601.09
#
# [408 rows x 3 columns]

# %%
#of course its much easier to merge and have both formats than making a million functions converting timestamps
result = pd.concat([price_data,mike_df], axis=1, join='inner')
result
# Out:
#                 time_str    close   volume                created_at  \
# 0    2019-10-15 00:00:00  8378.45  1464.67 2019-10-15 00:00:00+00:00
# 1    2019-10-15 01:00:00  8342.38   464.00 2019-10-15 01:00:00+00:00
# 2    2019-10-15 02:00:00  8351.43   487.40 2019-10-15 02:00:00+00:00
# 3    2019-10-15 03:00:00  8329.13   332.29 2019-10-15 03:00:00+00:00
# 4    2019-10-15 04:00:00  8350.23   528.90 2019-10-15 04:00:00+00:00
# ..                   ...      ...      ...                       ...
# 403  2019-10-31 19:00:00  9251.18   796.60 2019-10-31 19:00:00+00:00
# 404  2019-10-31 20:00:00  9197.68  1888.84 2019-10-31 20:00:00+00:00
# 405  2019-10-31 21:00:00  9144.69  4624.81 2019-10-31 21:00:00+00:00
# 406  2019-10-31 22:00:00  9136.74   846.99 2019-10-31 22:00:00+00:00
# 407  2019-10-31 23:00:00  9157.52   601.09 2019-10-31 23:00:00+00:00
#
#      negative   neutral  positive
# 0    0.789136  0.175218  0.243769
# 1    0.800804  0.142810  0.156272
# 2    0.807638  0.149722  0.189712
# 3    0.812648  0.146242  0.183761
# 4    0.794686  0.160486  0.204969
# ..        ...       ...       ...
# 403  0.825726  0.129344  0.152173
# 404  0.829012  0.127700  0.153295
# 405  0.845378  0.117862  0.135068
# 406  0.826362  0.119918  0.131794
# 407  0.851836  0.112924  0.142856
#
# [408 rows x 7 columns]

# %%
#mike_df['time_str']

# %%
#def datetime_fixer(df, row=0, column=['created_at']):
    #"""Convert datetime into string and back to PROPER datetime"""
    #reformed_timestamp = df.iloc[0][row].strftime("%Y-%m-%d %H:%M:%S")
        #df['date'][hour] = datetime.strptime(reformed_timestamp, '%Y-%m-%d %H:%M:%S')

    #return reformed_timestamp

# %%
#datetime_fixer(mike_df)

# %%
#def last_datetime(df):    
    #"""Sorts through articles and tokenizes text"""
    #df['tokens'] = df.apply(lambda row : datetime_fixer([row]['created_at']), axis = 1) 
   
    #return df

# %%
#last_datetime(mike_df)

# %%
result.plot(x='created_at', y='positive')
