# %%
import pandas as pd
import os
import datetime as dt

# %%
unpickled_df = pd.read_pickle("../../data/clean/twitter_sentiment3.pkl")
unpickled_df
# Out:
#                     created_at      screen_name  \
# 0    2019-10-31 23:58:56+00:00       Ricky_P007
# 1    2019-10-31 23:58:56+00:00  KennedyPattiso1
# 2    2019-10-31 23:58:55+00:00      BtcEthereum
# 3    2019-10-31 23:58:52+00:00    erickchan_XLM
# 4    2019-10-31 23:58:50+00:00     Researchiing
# ...                        ...              ...
# 4995 2019-10-27 13:41:36+00:00          PopME19
# 4996 2019-10-27 13:41:34+00:00      digifuture1
# 4997 2019-10-27 13:41:29+00:00          Ajneri4
# 4998 2019-10-27 13:41:29+00:00      lightifyco1
# 4999 2019-10-27 13:41:25+00:00     CryptoFozzie
#
#                                               full_text                   id  \
# 0     RT @Delta_Exchange: How many coin logos do you...  1190055587255422977
# 1     RT @XRPcryptowolf: Intercontinental Exchange (...  1190055584910991360
# 2     Bitcoin Needs ‘Real Use Cases’ to Become Digit...  1190055581886775297
# 3     @CyhChloe @johnkim77 @jasminecoin @codeyisfun ...  1190055568678895618
# 4     RT @zerohedge: 11 Years Ago Today Satoshi Naka...  1190055561682964481
# ...                                                 ...                  ...
# 4995  RT @satasion: Giveaway Alert! 🚨 No.3\n- Hallow...  1188450678965800960
# 4996  RT @Lionel46294550: #xrp #xrpcommunity #btc #e...  1188450670157926400
# 4997  RT @CoinEmergency: Hmm $BTC...do YOU want $20 ...  1188450649010126848
# 4998  RT @webnowcompany: The world’s leading Bitcoin...  1188450648842493953
# 4999  RT @_blockandchain_: Crypto Twitter be like......  1188450632287637505
#
#      lang  user_favourites_count  user_followers_count  user_friends_count  \
# 0      en                    532                    84                 246
# 1      en                  17182                  1051                1969
# 2      en                    384                   351                 526
# 3      en                   3051                   388                1086
# 4      en                      8                    12                  30
# ...   ...                    ...                   ...                 ...
# 4995   en                   1569                   352                1342
# 4996   en                    318                    18                  50
# 4997   en                   5150                   239                 972
# 4998   en                   8675                  1114                  60
# 4999   en                    986                   115                 501
#
#                        user_location  \
# 0               Citeureup, Indonesia
# 1                      Liechtenstein
# 2                        Cyber Space
# 3                           Cambodia
# 4                               None
# ...                              ...
# 4995                            None
# 4996                   United States
# 4997  Cagayan De Oro City, Northern
# 4998                 California, USA
# 4999                      MuppetMewn
#
#                                  user_profile_image_url  ...  \
# 0     http://pbs.twimg.com/profile_images/1188757498...  ...
# 1     http://pbs.twimg.com/profile_images/3788000000...  ...
# 2     http://pbs.twimg.com/profile_images/8792232595...  ...
# 3     http://pbs.twimg.com/profile_images/1174348587...  ...
# 4     http://abs.twimg.com/sticky/default_profile_im...  ...
# ...                                                 ...  ...
# 4995  http://pbs.twimg.com/profile_images/1189525743...  ...
# 4996  http://pbs.twimg.com/profile_images/1148685489...  ...
# 4997  http://pbs.twimg.com/profile_images/1183553750...  ...
# 4998  http://pbs.twimg.com/profile_images/7345596857...  ...
# 4999  http://pbs.twimg.com/profile_images/1144121445...  ...
#
#                                                mentions  \
# 0                                      [Delta_Exchange]
# 1                                       [XRPcryptowolf]
# 2                                                    []
# 3     [CyhChloe, johnkim77, jasminecoin, codeyisfun,...
# 4                                           [zerohedge]
# ...                                                 ...
# 4995                               [satasion, satasion]
# 4996                                   [Lionel46294550]
# 4997                     [CoinEmergency, CoinEmergency]
# 4998                                    [webnowcompany]
# 4999                                  [_blockandchain_]
#
#                                             mention_ids quoted_quote_count  \
# 0                                  [994891951160864769]                NaN
# 1                                  [944462285573099520]                NaN
# 2                                                    []                NaN
# 3     [1059871115236073473, 26448153, 11864798016930...                NaN
# 4                                            [18856867]                NaN
# ...                                                 ...                ...
# 4995         [1178370879144771585, 1178370879144771585]                NaN
# 4996                              [1030881852486307840]                8.0
# 4997         [1010151437224022022, 1010151437224022022]                NaN
# 4998                              [1052519189989269504]                NaN
# 4999                               [954018392146526208]                NaN
#
#      quoted_reply_count quoted_retweet_count  \
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
# ...                 ...                  ...
# 4995                NaN                  NaN
# 4996               11.0                 67.0
# 4997                NaN                  NaN
# 4998                NaN                  NaN
# 4999                NaN                  NaN
#
#                                            clean_tokens  compound  negative  \
# 0     [rt, deltaexchange, many, coin, logo, see, ima...       0.0     1.000
# 1     [rt, xrpcryptowolf, intercontinental, exchange...       0.0     0.865
# 2     [bitcoin, need, real, use, case, become, digit...       0.0     1.000
# 3     [cyhchloe, johnkim, jasminecoin, codeyisfun, c...       0.0     0.732
# 4     [rt, zerohedge, year, ago, today, satoshi, nak...       0.0     1.000
# ...                                                 ...       ...       ...
# 4995  [rt, satasion, giveaway, alert, halloween, edi...       0.0     0.448
# 4996  [rt, lionel, xrp, xrpcommunity, btc, eth, ltc,...       0.0     0.842
# 4997  [rt, coinemergency, hmm, btcdo, want, rt, like...       0.0     0.588
# 4998  [rt, webnowcompany, world, leading, bitcoin, c...       0.0     0.738
# 4999  [rt, blockandchain, crypto, twitter, likebitcoin]       0.0     1.000
#
#      neutral  positive
# 0      0.000    0.0000
# 1      0.135    0.3612
# 2      0.000    0.0000
# 3      0.268    0.5106
# 4      0.000    0.0000
# ...      ...       ...
# 4995   0.552    0.9062
# 4996   0.158    0.4927
# 4997   0.412    0.7184
# 4998   0.262    0.4939
# 4999   0.000    0.0000
#
# [5000 rows x 23 columns]

# %%
#unpickled_df2 = pd.read_pickle("../../data/clean/twitter_sentiment2.pkl")
#unpickled_df2

# %%
price_data = pd.read_csv("../../data/price_data/bitcoin_hourly.csv", index_col="date_time")
price_data
# Out:
#                        close  volumefrom
# date_time
# 2019-10-15 00:00:00  8378.45     1464.67
# 2019-10-15 01:00:00  8342.38      464.00
# 2019-10-15 02:00:00  8351.43      487.40
# 2019-10-15 03:00:00  8329.13      332.29
# 2019-10-15 04:00:00  8350.23      528.90
# ...                      ...         ...
# 2019-10-31 19:00:00  9251.18      796.60
# 2019-10-31 20:00:00  9197.68     1888.84
# 2019-10-31 21:00:00  9144.69     4624.81
# 2019-10-31 22:00:00  9136.74      846.99
# 2019-10-31 23:00:00  9157.52      601.09
#
# [408 rows x 2 columns]

# %%
#price_data.groupby(pd.Grouper(key='date_time', freq='60m', axis=1))

# %%
#head=unpickled_df.head(10)

# %%
#head

# %%
#test_df = unpickled_df[['created_at', 'compound', 'id', 'user_favourites_count', 'screen_name']].copy()
#test_df

# %%
#test = test_df.drop_duplicates(subset=['compound'])
#test

# %%
#binned_df = test_df.groupby([test_df['created_at'].dt.to_period('H'), 'user_favourites_count']).count().unstack()
# Droping unnecessary column level
#binned_df.columns = binned_df.columns.droplevel()
#binned_df.plot(kind='bar', legend=False)

# %%
#binned_df

# %%
#grouped_df = test_df.groupby([test_df['created_at'].dt.to_period('H'), 'user_favourites_count', 'screen_name', 'compound', 'id'])
#big_df

# %%
#df = pd.DataFrame(grouped_df.size().reset_index(level=['created_at']))
#df

# %%
#df.to_csv('model.csv')

# %%
#binned_d = price_data.groupby([price_data['date_time'].dt.to_period('D'), 'close']).count().unstack()
# Droping unnecessary column level
#binned_d.columns = binned_d.columns.droplevel()
#binned_d.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c0a8a4b6fb87> in <module>
# ----> 1 binned_d = price_data.groupby([price_data['date_time'].dt.to_period('D'), 'close']).count().unstack()
#       2 # Droping unnecessary column level
#       3 binned_d.columns = binned_d.columns.droplevel()
#       4 binned_d.plot(kind='bar')
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     341             pass  # we raise an attribute error anyway
#     342
# --> 343         raise AttributeError("Can only use .dt accessor with datetimelike " "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
model_data = unpickled_df[['created_at', 'negative', 'neutral', 'positive', 'clean_tokens']].copy()
model_data
# Out:
#                     created_at  negative  neutral  positive  \
# 0    2019-10-31 23:58:56+00:00     1.000    0.000    0.0000
# 1    2019-10-31 23:58:56+00:00     0.865    0.135    0.3612
# 2    2019-10-31 23:58:55+00:00     1.000    0.000    0.0000
# 3    2019-10-31 23:58:52+00:00     0.732    0.268    0.5106
# 4    2019-10-31 23:58:50+00:00     1.000    0.000    0.0000
# ...                        ...       ...      ...       ...
# 4995 2019-10-27 13:41:36+00:00     0.448    0.552    0.9062
# 4996 2019-10-27 13:41:34+00:00     0.842    0.158    0.4927
# 4997 2019-10-27 13:41:29+00:00     0.588    0.412    0.7184
# 4998 2019-10-27 13:41:29+00:00     0.738    0.262    0.4939
# 4999 2019-10-27 13:41:25+00:00     1.000    0.000    0.0000
#
#                                            clean_tokens
# 0     [rt, deltaexchange, many, coin, logo, see, ima...
# 1     [rt, xrpcryptowolf, intercontinental, exchange...
# 2     [bitcoin, need, real, use, case, become, digit...
# 3     [cyhchloe, johnkim, jasminecoin, codeyisfun, c...
# 4     [rt, zerohedge, year, ago, today, satoshi, nak...
# ...                                                 ...
# 4995  [rt, satasion, giveaway, alert, halloween, edi...
# 4996  [rt, lionel, xrp, xrpcommunity, btc, eth, ltc,...
# 4997  [rt, coinemergency, hmm, btcdo, want, rt, like...
# 4998  [rt, webnowcompany, world, leading, bitcoin, c...
# 4999  [rt, blockandchain, crypto, twitter, likebitcoin]
#
# [5000 rows x 5 columns]

# %%
#bins by the hour
grouped_model = model_data.groupby([model_data['created_at'].dt.to_period('H'), 'negative', 'positive', 'neutral'])

# %%
#change groupbyDataFrame to regular df
model_df = pd.DataFrame(grouped_model.size().reset_index(level=['created_at']))
model_df
# Out:
#                                  created_at    0
# negative positive neutral
# 0.224     0.6597  0.448    2019-10-27 13:00    1
# 0.248    -0.8934  0.268    2019-10-27 13:00    1
# 0.286     0.3612  0.714    2019-10-27 13:00    1
# 0.316    -0.9042  0.168    2019-10-27 13:00    1
#           0.8689  0.684    2019-10-27 13:00    1
# ...                                     ...  ...
# 0.922     0.3182  0.078    2019-10-31 23:00    1
# 0.925     0.3612  0.075    2019-10-31 23:00    1
# 0.936     0.1280  0.064    2019-10-31 23:00    1
# 0.950     0.0258  0.050    2019-10-31 23:00    1
# 1.000     0.0000  0.000    2019-10-31 23:00  237
#
# [2225 rows x 2 columns]
