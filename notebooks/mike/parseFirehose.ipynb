# %%
import pprint as pp
import json
from pathlib import Path
import pandas as pd

# %%
twitter_hose = Path('../../../data/dirty/pushshift.io/twitter/samplehose_hourly/SH_tweets_2019-10-05-01_filtered.json')

# %%
all_tweets = []

with open(twitter_hose, encoding='utf-8') as f:
    for line in f:
        data = json.loads(line)
        #pp.pprint(data)
        #break
        
        captured_fields = {
        "created_at" : data['created_at'],
        "screen_name" : data['user']['screen_name'],
        "full_text" : data['text'],
        "geo" : data['geo'],
        "contributors" : data['contributors'],
        "id": data["id"],
        "lang": data["lang"],
        "retweet_count": data["retweet_count"]
        }
        
        if 'extended_tweet' in data:
            captured_fields['full_text'] = data['extended_tweet']['full_text']
            
        all_tweets.append(captured_fields)

# %%
pp.pprint(all_tweets[0])
df = pd.DataFrame(all_tweets)
df.head()
# Out:
# {'contributors': None,
#  'created_at': 'Sat Oct 05 01:32:28 +0000 2019',
#  'full_text': '#Disney is hiring a Digital #Sales #Planner  (Project Hire) in '
#               '#Burbank, apply now! #job https://t.co/oB8TH6c3sn #DisneyJobs '
#               'https://t.co/bXNrKG3lzV',
#  'geo': None,
#  'id': 1180294652643151872,
#  'lang': 'en',
#  'retweet_count': 0,
#  'screen_name': 'BethMerrick5'}
#   contributors                      created_at  \
# 0         None  Sat Oct 05 01:32:28 +0000 2019
# 1         None  Sat Oct 05 01:32:30 +0000 2019
# 2         None  Sat Oct 05 01:32:40 +0000 2019
# 3         None  Sat Oct 05 01:33:02 +0000 2019
# 4         None  Sat Oct 05 01:33:11 +0000 2019
#
#                                            full_text   geo  \
# 0  #Disney is hiring a Digital #Sales #Planner  (...  None
# 1                            https://t.co/yLtd6MyTkd  None
# 2  @realDonaldTrump @FoxNews https://t.co/vk7ct7Ats3  None
# ...

# %%
df[df['full_text'].str.contains('crypto')]
# Out:
#                          created_at  \
# 32   Sat Oct 05 01:35:02 +0000 2019
# 147  Sat Oct 05 01:45:44 +0000 2019
# 161  Sat Oct 05 01:46:47 +0000 2019
# 198  Sat Oct 05 01:50:08 +0000 2019
#
#                                              full_text      screen_name
# 32   RT @XRPcryptowolf: 200 $XRP #GIVEAWAY\n\nSpons...       toanphamhd
# 147  RT @JessumDoode: @22centurycrypto Separate CSW...         23pluton
# 161  RT @cryptounfolded: #Bitcoin Twitter mentions ...       chrismezzz
# 198  @coincodecap @ParticlProject It's amazing ! I ...  JeremyS24205084

# %%
df[df['full_text'].str.contains('BTC')]
# Out:
#                          created_at  \
# 50   Sat Oct 05 01:36:43 +0000 2019
# 149  Sat Oct 05 01:46:06 +0000 2019
# 225  Sat Oct 05 01:52:35 +0000 2019
#
#                                              full_text      screen_name
# 50   🌈World's First‼🌈\n\nGold price link BTC 100% s...      chiaki95159
# 149  買いが弱くなってる？\nこれの見方未だ良く理解出来ていない\n#BTC https://t....  qnfb0YWbXPmcWqo
# 225  @doug3rd @princeantenor @brucefenton It may no...       beernameno

# %%
df[df['full_text'].str.contains('ETH')]
# Out:
#                          created_at                     full_text screen_name
# 117  Sat Oct 05 01:42:03 +0000 2019  @jasminexETH got finessed...      773Emo

# %%
{'contributors': None,
 'coordinates': None,
 'created_at': 'Sat Oct 05 01:32:28 +0000 2019',
 'display_text_range': [0, 140],
 'entities': {'hashtags': [{'indices': [0, 7], 'text': 'Disney'},
                           {'indices': [28, 34], 'text': 'Sales'},
                           {'indices': [35, 43], 'text': 'Planner'},
                           {'indices': [63, 71], 'text': 'Burbank'},
                           {'indices': [84, 88], 'text': 'job'}],
              'symbols': [],
              'urls': [{'display_url': 'workfor.us/disneycareers/…',
                        'expanded_url': 'https://workfor.us/disneycareers/3ov5z',
                        'indices': [89, 112],
                        'url': 'https://t.co/oB8TH6c3sn'},
                       {'display_url': 'twitter.com/i/web/status/1…',
                        'expanded_url': 'https://twitter.com/i/web/status/1180294652643151872',
                        'indices': [114, 137],
                        'url': 'https://t.co/4uVd6GarLH'}],
              'user_mentions': []},
 'extended_tweet': {'display_text_range': [0, 124],
                    'entities': {'hashtags': [{'indices': [0, 7],
                                               'text': 'Disney'},
                                              {'indices': [28, 34],
                                               'text': 'Sales'},
                                              {'indices': [35, 43],
                                               'text': 'Planner'},
                                              {'indices': [63, 71],
                                               'text': 'Burbank'},
                                              {'indices': [84, 88],
                                               'text': 'job'},
                                              {'indices': [113, 124],
                                               'text': 'DisneyJobs'}],
                                 'media': [{'display_url': 'pic.twitter.com/bXNrKG3lzV',
                                            'expanded_url': 'https://twitter.com/BethMerrick5/status/1180294652643151872/photo/1',
                                            'id': 1180294651632328705,
                                            'id_str': '1180294651632328705',
                                            'indices': [125, 148],
                                            'media_url': 'http://pbs.twimg.com/media/EGE_u3DWoAEY9WW.jpg',
                                            'media_url_https': 'https://pbs.twimg.com/media/EGE_u3DWoAEY9WW.jpg',
                                            'sizes': {'large': {'h': 600,
                                                                'resize': 'fit',
                                                                'w': 1055},
                                                      'medium': {'h': 600,
                                                                 'resize': 'fit',
                                                                 'w': 1055},
                                                      'small': {'h': 387,
                                                                'resize': 'fit',
                                                                'w': 680},
                                                      'thumb': {'h': 150,
                                                                'resize': 'crop',
                                                                'w': 150}},
                                            'type': 'photo',
                                            'url': 'https://t.co/bXNrKG3lzV'}],
                                 'symbols': [],
                                 'urls': [{'display_url': 'workfor.us/disneycareers/…',
                                           'expanded_url': 'https://workfor.us/disneycareers/3ov5z',
                                           'indices': [89, 112],
                                           'url': 'https://t.co/oB8TH6c3sn'}],
                                 'user_mentions': []},
                    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/bXNrKG3lzV',
                                                     'expanded_url': 'https://twitter.com/BethMerrick5/status/1180294652643151872/photo/1',
                                                     'id': 1180294651632328705,
                                                     'id_str': '1180294651632328705',
                                                     'indices': [125, 148],
                                                     'media_url': 'http://pbs.twimg.com/media/EGE_u3DWoAEY9WW.jpg',
                                                     'media_url_https': 'https://pbs.twimg.com/media/EGE_u3DWoAEY9WW.jpg',
                                                     'sizes': {'large': {'h': 600,
                                                                         'resize': 'fit',
                                                                         'w': 1055},
                                                               'medium': {'h': 600,
                                                                          'resize': 'fit',
                                                                          'w': 1055},
                                                               'small': {'h': 387,
                                                                         'resize': 'fit',
                                                                         'w': 680},
                                                               'thumb': {'h': 150,
                                                                         'resize': 'crop',
                                                                         'w': 150}},
                                                     'type': 'photo',
                                                     'url': 'https://t.co/bXNrKG3lzV'}]},
                    'full_text': '#Disney is hiring a Digital #Sales #Planner  '
                                 '(Project Hire) in #Burbank, apply now! #job '
                                 'https://t.co/oB8TH6c3sn #DisneyJobs '
                                 'https://t.co/bXNrKG3lzV'},
 'favorite_count': 0,
 'favorited': False,
 'filter_level': 'low',
 'geo': None,
 'id': 1180294652643151872,
 'id_str': '1180294652643151872',
 'in_reply_to_screen_name': None,
 'in_reply_to_status_id': None,
 'in_reply_to_status_id_str': None,
 'in_reply_to_user_id': None,
 'in_reply_to_user_id_str': None,
 'is_quote_status': False,
 'lang': 'en',
 'place': None,
 'possibly_sensitive': False,
 'quote_count': 0,
 'reply_count': 0,
 'retrieved_on': 1570239154.2715209,
 'retweet_count': 0,
 'retweeted': False,
 'source': '<a href="http://workfor.us/jobboard" rel="nofollow">Work For '
           'Us</a>',
 'text': '#Disney is hiring a Digital #Sales #Planner  (Project Hire) in '
         '#Burbank, apply now! #job https://t.co/oB8TH6c3sn… '
         'https://t.co/4uVd6GarLH',
 'timestamp_ms': '1570239148661',
 'truncated': True,
 'user': {'contributors_enabled': False,
          'created_at': 'Tue Feb 02 20:38:26 +0000 2016',
          'default_profile': True,
          'default_profile_image': False,
          'description': 'recruiter, Disney fan, Seminole, mom, scrapbooker, '
                         'run for fun, reader ** all opinions are my own**',
          'favourites_count': 1296,
          'follow_request_sent': None,
          'followers_count': 407,
          'following': None,
          'friends_count': 187,
          'geo_enabled': False,
          'id': 4872493179,
          'id_str': '4872493179',
          'is_translator': False,
          'lang': None,
          'listed_count': 38,
          'location': None,
          'name': 'Beth Merrick',
          'notifications': None,
          'profile_background_color': 'F5F8FA',
          'profile_background_image_url': '',
          'profile_background_image_url_https': '',
          'profile_background_tile': False,
          'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4872493179/1456420482',
          'profile_image_url': 'http://pbs.twimg.com/profile_images/696353488972992512/2DVSfTI6_normal.jpg',
          'profile_image_url_https': 'https://pbs.twimg.com/profile_images/696353488972992512/2DVSfTI6_normal.jpg',
          'profile_link_color': '1DA1F2',
          'profile_sidebar_border_color': 'C0DEED',
          'profile_sidebar_fill_color': 'DDEEF6',
          'profile_text_color': '333333',
          'profile_use_background_image': True,
          'protected': False,
          'screen_name': 'BethMerrick5',
          'statuses_count': 14659,
          'time_zone': None,
          'translator_type': 'none',
          'url': 'http://www.disneycareers.com',
          'utc_offset': None,
          'verified': False}}
