# %%
from libs import sentimentframe
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mferb\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = sentimentframe.sentiment_df("bitcoin",tokenize=True,sentiment=True)

# %%
df.head()
# Out:
#          date search_term       source  \
# 0  2019-11-03     bitcoin        Wired
# 1  2019-10-19     bitcoin     Engadget
# 2  2019-10-16     bitcoin     Mashable
# 3  2019-10-16     bitcoin  Gizmodo.com
# 4  2019-11-01     bitcoin  Gizmodo.com
#
#                                                  url          author  \
# 0  https://www.wired.com/story/iceland-bitcoin-mi...  Laura Mallonee
# 1  https://www.engadget.com/2019/10/19/htcs-exodu...  Igor Bonifacic
# 2  https://mashable.com/article/dark-web-child-po...      Jack Morse
# 3  https://gizmodo.com/huge-child-porn-ring-buste...      Matt Novak
# 4  https://gizmodo.com/french-students-will-now-h...  Jennings Brown
#
#                                                 text  \
# 0  Less than two miles from Icelands Reykjavik ai...
# 1  At least that's the idea. While it's not as in...
# 2  Say it with me: Bitcoin is not anonymous. \r\n...
# 3  Federal authorities in the U.S. have unsealed ...
# ...
